# %%
num1 = 36
num2 = 11

def fun(num1, num2):
    if(num1<num2):
        return num1
    else:
        return num2
    

print(fun(num1,num2))
# Out:
# 11

# %%
def welcome():
    print("Welcome to Python Programming!")

welcome()
welcome()
welcome()
# Out:
# Welcome to Python Programming!
# Welcome to Python Programming!
# Welcome to Python Programming!

# %%
def square(num):
    return num*num

num= int(input("Enter Number: "))
print(square(num))
# Out:
# 100

# %%
def add_number(a,b):
    return a+b


a = int(input("Enter First Number : "))
b = int(input("Enter sec Number : "))

print(add_number(a,b))
# Out:
# 5

# %%
def greet(name="Guest"):
    print("Hello, ",name)

greet("Abhay")
greet()
# Out:
# Hello,  Abhay
# Hello,  Guest

# %%
def avg(a,b,c):
    return (a+b+c)/3


a = int(input("Enter First Number : "))
b = int(input("Enter sec Number : "))
c = int(input("Enter There Number : "))

print(avg(a,b,c))
# Out:
# 3.0

# %%
.
.
